# %%
#importing modules

#####################################################################
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#####################################################################


#importing our final dataset, which i saved into a csv file in datasets folder

final_data = pd.read_csv('../datasets/fData.csv')

# %%
final_data = final_data.iloc[:,2:]
#slicing fips codes and redundant column before i calculate the corr coefs

# %%
final_data.head()
# Out:
#    agi_stub       N1   MARS1   MARS2   MARS4  NUMDEP    A00100    A02650  \
# 0         1  11670.0  6490.0  1350.0  3690.0  8320.0  151738.0  154057.0
# 1         2   6170.0  2340.0  1860.0  1780.0  5060.0  221418.0  223660.0
# 2         3   3510.0   890.0  2060.0   510.0  2930.0  216765.0  218614.0
# 3         4   2490.0   310.0  2020.0   120.0  2350.0  214326.0  215946.0
# 4         5   2760.0   130.0  2540.0    50.0  2860.0  364264.0  367190.0
#
#    total_people  agi_per_person State   County  Population Estimate, 2013  \
# 0       17510.0        8.665791    AL  Autauga                    54792.0
# 1       11120.0       19.911691    AL  Autauga                    54792.0
# 2        7940.0       27.300378    AL  Autauga                    54792.0
# 3        6700.0       31.988955    AL  Autauga                    54792.0
# 4        8070.0       45.138042    AL  Autauga                    54792.0
#
#    PCT_DIABETES_ADULTS13  PCT_OBESE_ADULTS13  FOODINSEC_13_15  VLFOODSEC_13_15
# 0                   13.0                34.1             17.6              7.3
# 1                   13.0                34.1             17.6              7.3
# 2                   13.0                34.1             17.6              7.3
# 3                   13.0                34.1             17.6              7.3
# 4                   13.0                34.1             17.6              7.3

# %%
# function to create the correlation heatmap for a dataframe

def createHeatMapForAgi(df):
    corelation_matrix = df.corr()
    plt.figure(figsize = (16,5))
    sns.heatmap(corelation_matrix, xticklabels=corelation_matrix.columns, yticklabels=corelation_matrix.columns, annot=True,linewidth = 0.5)

# %%
##generate heatmap for different agi_stub, observe the negative values in the matrix, of health data and the income data, 
##which does indicate that increase in wealth is decreaseing the diabetes and obesity

for i in range(1,6):
    agi_stub_i = final_data.loc[final_data['agi_stub'] == i]
    createHeatMapForAgi(agi_stub_i)
